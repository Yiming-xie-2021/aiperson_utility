# %% [markdown]
# <a href="https://colab.research.google.com/github/Yiming-xie-2021/aiperson_utility/blob/main/Synthetic_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# link drive
from google.colab import drive
drive.mount('/content/drive')

# download a specific model to the drive
if False:
  # !git lfs install
  # !git clone https://huggingface.co/unsloth/Qwen3-1.7B-unsloth-bnb-4bit /content/drive/MyDrive/models/Qwen3-1.7B-unsloth-bnb-4bit

# list of models under the path
import os

path = "/content/drive/MyDrive/models/"
for f in os.listdir(path):
    print(f)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Qwen3-1.7B-unsloth-bnb-4bit

# %%
# @title Installation

# %%capture
import os
# !pip install --upgrade -qqq uv
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install!
    # !pip install unsloth vllm synthetic-data-kit==0.0.3
else:
    try: import numpy; get_numpy = f"numpy=={numpy.__version__}"
    except: get_numpy = "numpy"
    try: import subprocess; is_t4 = "Tesla T4" in str(subprocess.check_output(["nvidia-smi"]))
    except: is_t4 = False
    get_vllm, get_triton = ("vllm==0.9.2", "triton==3.2.0") if is_t4 else ("vllm==0.10.2", "triton")
    # !uv pip install -qqq "Pillow<10.0.0" # Ensure Pillow is compatible with torchvision
    # !uv pip install -qqq --upgrade         unsloth {get_vllm} {get_numpy} torchvision bitsandbytes xformers
    # !uv pip install -qqq {get_triton}
    # !uv pip install synthetic-data-kit==0.0.3
# !uv pip install transformers==4.55.4
# !uv pip install --no-deps trl==0.22.2

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
# !pip install --upgrade -qqq uv
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install!
    # !pip install unsloth vllm
else:
    try: import numpy; get_numpy = f"numpy=={numpy.__version__}"
    except: get_numpy = "numpy"
    try: import subprocess; is_t4 = "Tesla T4" in str(subprocess.check_output(["nvidia-smi"]))
    except: is_t4 = False
    get_vllm, get_triton = ("vllm==0.9.2", "triton==3.2.0") if is_t4 else ("vllm==0.10.2", "triton")
    # !uv pip install -qqq --upgrade \
        unsloth {get_vllm} {get_numpy} torchvision bitsandbytes xformers
    # !uv pip install -qqq {get_triton}
# !uv pip install transformers==4.55.4
# !uv pip install --no-deps trl==0.22.2

# %% [markdown]
# ### Unsloth

# %%
from unsloth.dataprep import SyntheticDataKit

generator = SyntheticDataKit.from_pretrained(
    # Choose any model from https://huggingface.co/unsloth
    # model_name = "unsloth/Qwen3-4B-unsloth-bnb-4bit", #"unsloth/Llama-3.2-3B-Instruct"
    model_name = "/content/drive/MyDrive/models/Qwen3-1.7B-unsloth-bnb-4bit",
    max_seq_length = 2048, # Longer sequence lengths will be slow
    # load_in_4bit = True,
    # load_in_8bit = False,
    # full_finetuning = False,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 12-06 06:21:16 [__init__.py:244] Automatically detected platform cuda.
# ERROR 12-06 06:21:19 [fa_utils.py:57] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 12-06 06:21:31 [vllm_utils.py:702] Unsloth: Patching vLLM v1 graph capture
# INFO 12-06 06:21:31 [vllm_utils.py:732] Unsloth: Patching vLLM v0 graph capture
# Unsloth: Using dtype = torch.float16 for vLLM.
# Unsloth: vLLM loading /content/drive/MyDrive/models/Qwen3-1.7B-unsloth-bnb-4bit with actual GPU utilization = 89.39%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.74 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 2048. Num Sequences = 48.
# Unsloth: vLLM's KV Cache can use up to 11.78 GB. Also swap space = 0 GB.
# Unsloth: `cudagraph_mode` is not in `from vllm.config import CompilationConfig`
# Unsloth: Disabling `disable_cascade_attn` in vLLM to allow for better on policy RL!
# vLLM STDOUT: INFO 12-06 06:21:45 [__init__.py:244] Automatically detected platform cuda.
# vLLM STDOUT: INFO 12-06 06:21:47 [api_server.py:1395] vLLM API server version 0.9.2
# vLLM STDOUT: INFO 12-06 06:21:47 [cli_args.py:325] non-default args: {'model': '/content/drive/MyDrive/models/Qwen3-1.7B-unsloth-bnb-4bit', 'dtype': 'float16', 'seed': 0, 'max_model_len': 2048, 'quantization': 'bitsandbytes', 'max_logprobs': 0, 'disable_cascade_attn': True, 'load_format': 'bitsandbytes', 'gpu_memory_utilization': 0.8938626454842437, 'swap_space': 0.0, 'enable_prefix_caching': True, 'max_num_batched_tokens': 4096, 'max_num_seqs': 48, 'enable_chunked_prefill': True, 'disable_log_stats': True}
# vLLM STDOUT: INFO 12-06 06:22:04 [config.py:841] This model supports multiple tasks: {'reward', 'classify', 'generate', 'embed'}. Defaulting to 'generate'.
# vLLM STDOUT: WARNING 12-06 06:22:04 [config.py:3371] Casting torch.bfloat16 to torch.float16.
# vLLM STDOUT: INFO 12-06 06:22:04 [config.py:1472] Using max model len 2048
# vLLM STDOUT: WARNING 12-06 06:22:04 [config.py:960] bitsandbytes quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# vLLM STDOUT: WARNING 12-06 06:22:04 [arg_utils.py:1735] Compute Capability < 8.0 is not supported by the V1 Engine. Falling back to V0.
# vLLM STDOUT: INFO 12-06 06:22:07 [config.py:2285] Chunked prefill is enabled with max_num_batched_tokens=4096.
# vLLM STDOUT: INFO 12-06 06:22:07 [api_server.py:268] Started engine process with PID 5729
# vLLM STDOUT: INFO 12-06 06:22:20 [__init__.py:244] Automatically detected platform cuda.
# vLLM STDOUT: INFO 12-06 06:22:22 [llm_engine.py:230] Initializing a V0 LLM engine (v0.9.2) with config: model='/content/drive/MyDrive/models/Qwen3-1.7B-unsloth-bnb-4bit', speculative_config=None, tokenizer='/content/drive/MyDrive/models/Qwen3-1.7B-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=2048, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=/content/drive/MyDrive/models/Qwen3-1.7B-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":0,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":[],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":true,"cudagraph_num_of_warmups":0,"cudagraph_capture_sizes":[48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"max_capture_size":48,"local_cache_dir":null}, use_cached_outputs=True,
# vLLM STDOUT: INFO 12-06 06:22:23 [cuda.py:311] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# vLLM STDOUT: INFO 12-06 06:22:23 [cuda.py:360] Using XFormers backend.
# vLLM STDOUT: INFO 12-06 06:22:24 [parallel_state.py:1076] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# vLLM STDOUT: INFO 12-06 06:22:24 [model_runner.py:1171] Starting to load model /content/drive/MyDrive/models/Qwen3-1.7B-unsloth-bnb-4bit...
# vLLM STDOUT: INFO 12-06 06:22:26 [bitsandbytes_loader.py:499] Loading weights with BitsAndBytes quantization. May take a while ...
# vLLM STDOUT: INFO 12-06 06:23:19 [model_runner.py:1203] Model loading took 1.3928 GiB and 54.074278 seconds
# vLLM STDOUT: INFO 12-06 06:23:25 [worker.py:294] Memory profiling takes 5.20 seconds
# vLLM STDOUT: INFO 12-06 06:23:25 [worker.py:294] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.89) = 13.18GiB
# vLLM STDOUT: INFO 12-06 06:23:25 [worker.py:294] model weights take 1.39GiB; non_torch_memory takes 0.05GiB; PyTorch activation peak memory takes 0.37GiB; the rest of the memory reserved for KV Cache is 11.37GiB.
# vLLM STDOUT: INFO 12-06 06:23:25 [executor_base.py:113] # cuda blocks: 6653, # CPU blocks: 0
# vLLM STDOUT: INFO 12-06 06:23:25 [executor_base.py:118] Maximum concurrency for 2048 tokens per request: 51.98x
# vLLM STDOUT: INFO 12-06 06:23:25 [model_runner.py:1513] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# vLLM STDOUT: INFO 12-06 06:23:36 [model_runner.py:1671] Graph capturing finished in 11 secs, took 0.15 GiB
# vLLM STDOUT: INFO 12-06 06:23:36 [llm_engine.py:428] init engine (profile, create kv cache, warmup model) took 16.91 seconds
# vLLM STDOUT: WARNING 12-06 06:23:36 [config.py:1392] Default sampling parameters have been overridden by the model's Hugging Face generation config recommended from the model creator. If this is not intended, please relaunch vLLM instance with `--generation-config vllm`.
# vLLM STDOUT: INFO 12-06 06:23:36 [serving_chat.py:125] Using default chat sampling params from model: {'temperature': 0.6, 'top_k': 20, 'top_p': 0.95}
# vLLM STDOUT: INFO 12-06 06:23:36 [serving_completion.py:72] Using default completion sampling params from model: {'temperature': 0.6, 'top_k': 20, 'top_p': 0.95}
# vLLM STDOUT: INFO 12-06 06:23:36 [api_server.py:1457] Starting vLLM API server 0 on http://0.0.0.0:8000
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:29] Available routes are:
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /openapi.json, Methods: GET, HEAD
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /docs, Methods: GET, HEAD
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /docs/oauth2-redirect, Methods: GET, HEAD
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /redoc, Methods: GET, HEAD
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /health, Methods: GET
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /load, Methods: GET
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /ping, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /ping, Methods: GET
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /tokenize, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /detokenize, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /v1/models, Methods: GET
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /version, Methods: GET
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /v1/chat/completions, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /v1/completions, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /v1/embeddings, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /pooling, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /classify, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /score, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /v1/score, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /v1/audio/transcriptions, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /v1/audio/translations, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /rerank, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /v1/rerank, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /v2/rerank, Methods: POST
# vLLM Server Ready Detected
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /invocations, Methods: POST
# vLLM STDOUT: INFO 12-06 06:23:36 [launcher.py:37] Route: /metrics, Methods: GET
# vLLM STDOUT: INFO:     127.0.0.1:39628 - "GET /metrics HTTP/1.1" 200 OK

# %% [markdown]
# ## Generate QA Pairs + Auto clean data
# We now use synthetic data kit for question answer pair generation:

# %%
generator.prepare_qa_generation(
    output_folder = "/content/drive/MyDrive/ColabNotebooks/data", # Output location of synthetic data
    temperature = 0.7, # Higher temp makes more diverse datases
    top_p = 0.95, #0.95,
    overlap = 64, # Overlap portion during chunking
    max_generation_tokens = 512, # Can increase for longer QA pairs
)

# %% [markdown]
# Check if it succeeded:

# %%
# !synthetic-data-kit system-check
# Out:
# vLLM STDOUT: INFO:     127.0.0.1:41950 - "GET /v1/models HTTP/1.1" 200 OK
#  VLLM server is running at http://localhost:8000/v1
# Available models: {'object': 'list', 'data': [{'id':
# 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'object': 'model', 'created': 1760540489,
# 'owned_by': 'vllm', 'root': 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'parent': None,
# 'max_model_len': 2048, 'permission': [{'id':
# 'modelperm-9520b66b97214cf0a9c726d90cefbb98', 'object': 'model_permission',
# 'created': 1760540489, 'allow_create_engine': False, 'allow_sampling': True,
# 'allow_logprobs': True, 'allow_search_indices': False, 'allow_view': True,
# 'allow_fine_tuning': False, 'organization': '*', 'group': None, 'is_blocking':
# False}]}]}
# ⠋ Checking VLLM server at http://localhost:8000/v1...

# %% [markdown]
# ## Document Parsing (PDF, CSV, HTML etc.)
# Now, let's take the Byte Latent Transformer: Patches Scale Better Than Tokens research paper found at https://arxiv.org/abs/2412.09871 and covert it to Q&A pairs in order to finetune Llama 3.2!

# %%
# Byte Latent Transformer: Patches Scale Better Than Tokens paper in HTML format
# !synthetic-data-kit \
    -c synthetic_data_kit_config.yaml \
    ingest /content/drive/MyDrive/ColabNotebooks/zhihudata/huan2-merged_cleaned.txt

# Truncate document
filenames = generator.chunk_data("/content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned.txt")
print(len(filenames), filenames[:3])
# Out:
# ⠋ Processing
# /content/drive/MyDrive/ColabNotebooks/zhihudata/huan2-merged_cleaned.txt...
#  Text successfully extracted to
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned.txt
# 927 ['/content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_0.txt', '/content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_1.txt', '/content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_2.txt']

# %%
import os

output_dir = "/content/drive/MyDrive/ColabNotebooks/data/output/"
filenames = [os.path.join(output_dir, f) for f in os.listdir(output_dir) if f.startswith("huan2-merged_cleaned_") and f.endswith(".txt")]
filenames.sort() # Ensure consistent order
print(len(filenames), filenames[:3])
# Out:
# 927 ['/content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_0.txt', '/content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_1.txt', '/content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_10.txt']

# %% [markdown]
# We see around 37 chunks of data. We now call synthetic-data-kit to create some pairs of data for 3 of our chunks.
#
# You can process more chunks, but it'll be much slower!
#
# Using `--num-pairs` will generate **approximately** that many QA pairs. However it might be shorter or longer depending on the `max_seq_length` of the loaded up model. So if you specify 100, you might only get 10 since the model's max sequence length is capped.

# %%
import os

output_dir = "/content/drive/MyDrive/ColabNotebooks/data/output/"
# Count the number of files in the directory
file_count = len([f for f in os.listdir(output_dir) if os.path.isfile(os.path.join(output_dir, f))])
print(f"Total number of files in {output_dir}: {file_count}")
# Out:
# Total number of files in /content/drive/MyDrive/ColabNotebooks/data/output/: 928

# %%
# !ls -l
# Out:
# total 20
# drwxr-xr-x 12 root root 4096 Oct 10 15:50 data
# drwx------  5 root root 4096 Oct 10 15:50 drive
# drwxr-xr-x  1 root root 4096 Oct  8 13:53 sample_data
# -rw-r--r--  1 root root 3386 Oct 10 15:57 synthetic_data_kit_config.yaml
# drwxr-xr-x  4 root root 4096 Oct 10 15:44 unsloth_compiled_cache

# %%
import time
# Process 3 chunks for now -> can increase but slower!
for filename in filenames:
    # !synthetic-data-kit \
        -c synthetic_data_kit_config.yaml \
        create {filename} \
        --num-pairs 8 \
        --type "qa"
    time.sleep(1) # Sleep some time to leave some room for processing
# Out:
# Streaming output truncated to the last 5000 lines.
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# .vLLM STDOUT: INFO:     127.0.0.1:58664 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# Batch processing complete.
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# Generated 8 QA pairs total
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# Saving result to
# /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_430_qa
# _pairs.json
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# Successfully wrote test file to
# /content/drive/MyDrive/ColabNotebooks/data/generated/test_write.json
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# Successfully wrote result to
# /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_430_qa
# _pairs.json
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_430.txt..
# .
#  Content saved to
# /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_430_qa
# _pairs.json
# vLLM STDOUT: INFO:     127.0.0.1:58606 - "GET /v1/models HTTP/1.1" 200 OK
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# .vLLM STDOUT: INFO:     127.0.0.1:58610 - "GET /v1/models HTTP/1.1" 200 OK
# vLLM STDOUT: INFO 10-15 18:38:44 [logger.py:43] Received request chatcmpl-5d965211293d44c2a7acb99382309fb6: prompt: '<|im_start|>system\nSummarize this document in 3-5 sentences, focusing on the main topic and key concepts. /no_think\n<|im_end|>\n<|im_start|>user\n，嘉定销冠保利这次也被打脸了。即使售价已经低到大虹桥2017年水平，保利虹桥和著这次的认购率也仅有85%。当下5-800万的预算群体，对大虹桥新房越来越不买账。首先是新房端，大虹桥新房目前进入去库存阶段，项目之间的竞争依然比较激烈。目前已知库存1016套，加上尚未过会的一些房源以及上海城投华漕两块宅地，大虹桥的新房存量将在2000套以上：可以想象前有绿城春晓园、蟠龙里滞销，后有保利虹桥和著。其次是大虹桥的二手市场，9.29新政大虹桥大量二手次新增值税五改二，二手笋盘不断出现抢夺新房客户。以前大虹桥的新房好卖，原因之一是二手次新太贵不在同一个预算段内。现在天空之城、虹桥公馆的投资客在近几个月疯狂出逃，中区成交价都已经破发：就算你再喜欢大虹桥，一个是已经交付所见即所得的次新，一个是规划大饼，大家都卖5.6万你还不知道怎么选？全市视角来看，北虹之星的站位更加危险。在布局和总价段上跟南翔、上大、顾村、杨行，都没有拉开明显差距。单靠北虹之星已知的六块宅地的体量，片区想要引进个大商场、大医院也不太可能；北虹之星未来想成为泗泾地铁北侧那样的“睡城”片区，都还差一个5万方的花园城配套。第三点就是项目本身所处规划落地时间太长，有一定兑现风险。目前项目周边所见之处是施工围墙和坑坑洼洼的公路，城市界面十分劝退：如果放在三年前，北虹之星5.6万的新房一出，想必也是触发积分的存在；可惜生错了时代，位置最好的保利都卖不动的情况下，剩余13宗性质待定的地块，不是没有可能被划成保障房。到时候北虹之星直接降级为北虹大居，成了隔壁南翔云翔大居的直接竞品，区别在于隔壁的云翔湖据说直接不翼而飞了。江桥的市场本身就比较封闭，北虹之星的楼市作用，无非是为江桥创造一个比乐秀路更便宜的睡城。精研全市板块 独家买房买房逻辑分析私信免费咨询更多板块买房避坑建议这样看所谓上虹桥，也许也只是大虹桥体系下，一块新的“睡城”遮羞布了。中国人做事喜欢师出有名。当年明朝朱棣翻烂了史书寻找对漠北出兵的理由居然是报汉高祖刘邦白马之围的仇；同样，kfs翻烂了规划，终于找到了一年前就发布了，但毫无知名度的上虹桥规划来炒作。直接说想割韭菜就显得很low，但换成打造下一代国际社区/商务区，新一代城市人居新典范就高大上多了。kfs需要一个卖房的理由，买房者也需要一个说服自己买单的理由。今天说起金滩、前湾、大东方，很多人第一反应都不知道在哪，这就是营销的目的。总不能告诉你金滩是金杨、金桥拆不动的滨江，前湾是闵行华漕纪王镇，大东方是浦东机场和周边鸟不拉屎的一圈吧！对楼市来说，大虹桥已经算一个被用烂的梗了。光是徐泾、前湾和江桥这些年就供应了45块地，3万多套新房,大虹桥的概念更是不知道被营销了多少次：kfs这次特意绕开北虹桥，找到上虹桥概念，给韭菜们换了一把新镰刀。在营销包装之下，这里是基于大虹桥体系上更国际化、更宜居，更多美好词汇加身的一个升级版片区。不再强调这里是大虹桥，也不说这里是江桥发展最差的封浜。这里是寄存希望的全新规划——上虹桥，这下新韭菜们不得抢着送人头？\n\n【文章169：豪宅失意，中产得意，这里终于<|im_end|>\n<|im_start|>assistant\n', params: SamplingParams(n=1, presence_penalty=0.0, frequency_penalty=0.0, repetition_penalty=1.0, temperature=0.1, top_p=0.95, top_k=20, min_p=0.0, seed=None, stop=[], stop_token_ids=[], bad_words=[], include_stop_str_in_output=False, ignore_eos=False, max_tokens=512, min_tokens=0, logprobs=None, prompt_logprobs=None, skip_special_tokens=True, spaces_between_special_tokens=True, truncate_prompt_tokens=None, guided_decoding=None, extra_args=None), prompt_token_ids: None, prompt_embeds shape: None, lora_request: None, prompt_adapter_request: None.
# vLLM STDOUT: INFO 10-15 18:38:44 [engine.py:317] Added request chatcmpl-5d965211293d44c2a7acb99382309fb6.
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# .vLLM STDOUT: INFO:     127.0.0.1:58622 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# vLLM STDOUT: INFO 10-15 18:38:53 [logger.py:43] Received request chatcmpl-9122064fc0d04baa8cc2c2fe91ac2524: prompt: '<|im_start|>system\nCreate 4 question-answer pairs from this text for LLM training. /no_think\n\nRules:\n1. Questions must be about important facts in the text\n2. Answers must be directly supported by the text\n3. Return JSON format only:\n\n[\n  {\n    "question": "Question 1?",\n    "answer": "Answer 1."\n  },\n  {\n    "question": "Question 2?",\n    "answer": "Answer 2."\n  }\n]\n\nText:\n，嘉定销冠保利这次也被打脸了。即使售价已经低到大虹桥2017年水平，保利虹桥和著这次的认购率也仅有85%。当下5-800万的预算群体，对大虹桥新房越来越不买账。首先是新房端，大虹桥新房目前进入去库存阶段，项目之间的竞争依然比较激烈。目前已知库存1016套，加上尚未过会的一些房源以及上海城投华漕两块宅地，大虹桥的新房存量将在2000套以上：可以想象前有绿城春晓园、蟠龙里滞销，后有保利虹桥和著。其次是大虹桥的二手市场，9.29新政大虹桥大量二手次新增值税五改二，二手笋盘不断出现抢夺新房客户。以前大虹桥的新房好卖，原因之一是二手次新太贵不在同一个预算段内。现在天空之城、虹桥公馆的投资客在近几个月疯狂出逃，中区成交价都已经破发：就算你再喜欢大虹桥，一个是已经交付所见即所得的次新，一个是规划大饼，大家都卖5.6万你还不知道怎么选？全市视角来看，北虹之星的站位更加危险。在布局和总价段上跟南翔、上大、顾村、杨行，都没有拉开明显差距。单靠北虹之星已知的六块宅地的体量，片区想要引进个大商场、大医院也不太可能；北虹之星未来想成为泗泾地铁北侧那样的“睡城”片区，都还差一个5万方的花园城配套。第三点就是项目本身所处规划落地时间太长，有一定兑现风险。目前项目周边所见之处是施工围墙和坑坑洼洼的公路，城市界面十分劝退：如果放在三年前，北虹之星5.6万的新房一出，想必也是触发积分的存在；可惜生错了时代，位置最好的保利都卖不动的情况下，剩余13宗性质待定的地块，不是没有可能被划成保障房。到时候北虹之星直接降级为北虹大居，成了隔壁南翔云翔大居的直接竞品，区别在于隔壁的云翔湖据说直接不翼而飞了。江桥的市场本身就比较封闭，北虹之星的楼市作用，无非是为江桥创造一个比乐秀路更便宜的睡城。精研全市板块 独家买房买房逻辑分析私信免费咨询更多板块买房避坑建议这样看所谓上虹桥，也许也只是大虹桥体系下，一块新的“睡城”遮羞布了。中国人做事喜欢师出有名。当年明朝朱棣翻烂了史书寻找对漠北出兵的理由居然是报汉高祖刘邦白马之围的仇；同样，kfs翻烂了规划，终于找到了一年前就发布了，但毫无知名度的上虹桥规划来炒作。直接说想割韭菜就显得很low，但换成打造下一代国际社区/商务区，新一代城市人居新典范就高大上多了。kfs需要一个卖房的理由，买房者也需要一个说服自己买单的理由。今天说起金滩、前湾、大东方，很多人第一反应都不知道在哪，这就是营销的目的。总不能告诉你金滩是金杨、金桥拆不动的滨江，前湾是闵行华漕纪王镇，大东方是浦东机场和周边鸟不拉屎的一圈吧！对楼市来说，大虹桥已经算一个被用烂的梗了。光是徐泾、前湾和江桥这些年就供应了45块地，3万多套新房,大虹桥的概念更是不知道被营销了多少次：kfs这次特意绕开北虹桥，找到上虹桥概念，给韭菜们换了一把新镰刀。在营销包装之下，这里是基于大虹桥体系上更国际化、更宜居，更多美好词汇加身的一个升级版片区。不再强调这里是大虹桥，也不说这里是江桥发展最差的封浜。这里是寄存希望的全新规划——上虹桥，这下新韭菜们不得抢着送人头？\n<|im_end|>\n<|im_start|>assistant\n', params: SamplingParams(n=1, presence_penalty=0.0, frequency_penalty=0.0, repetition_penalty=1.0, temperature=0.7, top_p=0.95, top_k=20, min_p=0.0, seed=None, stop=[], stop_token_ids=[], bad_words=[], include_stop_str_in_output=False, ignore_eos=False, max_tokens=512, min_tokens=0, logprobs=None, prompt_logprobs=None, skip_special_tokens=True, spaces_between_special_tokens=True, truncate_prompt_tokens=None, guided_decoding=None, extra_args=None), prompt_token_ids: None, prompt_embeds shape: None, lora_request: None, prompt_adapter_request: None.
# vLLM STDOUT: INFO 10-15 18:38:53 [engine.py:317] Added request chatcmpl-9122064fc0d04baa8cc2c2fe91ac2524.
# Processing 2 chunks to generate QA pairs...
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_431.txt..
# ⠇ Generating qa content from
# ...
# vLLM STDOUT: INFO 10-15 18:41:38 [engine.py:317] Added request chatcmpl-2152aedea75c49eeb36289a6c4f97cde.
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# .vLLM STDOUT: INFO:     127.0.0.1:45712 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# vLLM STDOUT: INFO 10-15 18:41:48 [logger.py:43] Received request chatcmpl-426c3e41e3c2408aabf023c30673255b: prompt: '<|im_start|>system\nCreate 4 question-answer pairs from this text for LLM training. /no_think\n\nRules:\n1. Questions must be about important facts in the text\n2. Answers must be directly supported by the text\n3. Return JSON format only:\n\n[\n  {\n    "question": "Question 1?",\n    "answer": "Answer 1."\n  },\n  {\n    "question": "Question 2?",\n    "answer": "Answer 2."\n  }\n]\n\nText:\n【文章171：徐汇即将消失的板块，却成了未来潜力最大的地方】\n徐汇即将消失的板块，却成了未来潜力最大的地方。这就是龙华板块，已经掩没在徐汇滨江的盛名之下很久了。龙华板块示意图：龙华以前是郊区落乡之地，有烈士陵园、龙华机场、火葬场，并未承载多少世人的青睐。龙华单独成立过区，还划归过西郊区和上海县，与北部的“梧桐区”发展非常迥异。自从1984年并给徐汇后，龙华地区一直没有什么大的发展。徐汇只是拿它放置一些动迁房和工业厂房，龙华承担了一个底层的职能。徐汇的辉煌始于徐家汇，继而80年代改革开放的春风吹到漕河泾，而龙华成了被遗忘的角落。直到2010年，世博会的拆迁浪潮袭卷而来，龙华工业区才迎来了蜕变的契机。此时恰逢21世纪滨江CBD时代，龙华滨江工业区犹如凤凰涅槃，华丽转身为滨江豪宅和CBD。随后我们看到的就是，龙华的名号逐渐被徐汇滨江所取代。尽管\n<|im_end|>\n<|im_start|>assistant\n', params: SamplingParams(n=1, presence_penalty=0.0, frequency_penalty=0.0, repetition_penalty=1.0, temperature=0.7, top_p=0.95, top_k=20, min_p=0.0, seed=None, stop=[], stop_token_ids=[], bad_words=[], include_stop_str_in_output=False, ignore_eos=False, max_tokens=512, min_tokens=0, logprobs=None, prompt_logprobs=None, skip_special_tokens=True, spaces_between_special_tokens=True, truncate_prompt_tokens=None, guided_decoding=None, extra_args=None), prompt_token_ids: None, prompt_embeds shape: None, lora_request: None, prompt_adapter_request: None.
# ⠇ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠏ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# .vLLM STDOUT: INFO 10-15 18:41:48 [engine.py:317] Added request chatcmpl-426c3e41e3c2408aabf023c30673255b.
# ⠋ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠙ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠹ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠸ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠼ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠴ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠦ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# ⠧ Generating qa content from
# /content/drive/MyDrive/ColabNotebooks/data/output/huan2-merged_cleaned_436.txt..
# .

# %% [markdown]
# Optionally, you can clean up the data via pruning "bad" or low quality examples and convert the rest to JSON format for finetuning!

# %%
# !synthetic-data-kit \
#     -c synthetic_data_kit_config.yaml \
#     curate --threshold 0.0 \
#     "data/generated/arxiv_org_0_qa_pairs.json"

# %% [markdown]
# We now convert the generated datasets into QA formats so we can load it for finetuning:

# %%
qa_pairs_filenames = [
    f"/content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_{i}_qa_pairs.json"
    for i in range(len(filenames[:3]))
]
for filename in qa_pairs_filenames:
    # !synthetic-data-kit \
        -c synthetic_data_kit_config.yaml \
        save-as {filename} -f ft
# Out:
# ⠋ Converting data/generated/arxiv_org_0_qa_pairs.json to ft format with json
# storage...
# L Error: [Errno 2] No such file or directory:
# 'data/generated/arxiv_org_0_qa_pairs.json'
# ⠋ Converting data/generated/arxiv_org_1_qa_pairs.json to ft format with json
# storage...
# L Error: [Errno 2] No such file or directory:
# 'data/generated/arxiv_org_1_qa_pairs.json'
# ⠋ Converting data/generated/arxiv_org_2_qa_pairs.json to ft format with json
# storage...
# L Error: [Errno 2] No such file or directory:
# 'data/generated/arxiv_org_2_qa_pairs.json'

# %% [markdown]
# Let's load up the data and see what the synthetic data looks like!

# %%
from datasets import Dataset
import pandas as pd
final_filenames = [
    f"data/final/arxiv_org_{i}_qa_pairs_ft.json"
    for i in range(len(filenames[:3]))
]
conversations = pd.concat([
    pd.read_json(name) for name in final_filenames
]).reset_index(drop = True)

dataset = Dataset.from_pandas(conversations)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4257181148.py in <cell line: 0>()
#       6 ]
#       7 conversations = pd.concat([
# ----> 8     pd.read_json(name) for name in final_filenames
#       9 ]).reset_index(drop = True)
#      10
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     902             self.data = filepath_or_buffer
#     903         elif self.engine == "ujson":
# --> 904             data = self._get_data_from_filepath(filepath_or_buffer)
#     905             self.data = self._preprocess_data(data)
#     906
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in _get_data_from_filepath(self, filepath_or_buffer)
#     958             and not file_exists(filepath_or_buffer)
#     959         ):
# --> 960             raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     961         else:
#     962             warnings.warn(
#
# FileNotFoundError: File data/final/arxiv_org_0_qa_pairs_ft.json does not exist

# %%
dataset[0]
# Out:
# {'messages': [{'content': 'You are a helpful assistant.', 'role': 'system'},
#   {'content': 'What is the primary unit of computation in the Byte Latent Transformer (BLT) architecture?',
#    'role': 'user'},
#   {'content': 'Patches', 'role': 'assistant'}]}

# %%
dataset[1]
# Out:
# {'messages': [{'content': 'You are a helpful assistant.', 'role': 'system'},
#   {'content': 'How do patches in BLT architecture get segmented?',
#    'role': 'user'},
#   {'content': 'Based on the entropy of the next byte', 'role': 'assistant'}]}

# %%
dataset[-1]
# Out:
# {'messages': [{'content': 'You are a helpful assistant.', 'role': 'system'},
#   {'content': 'What is the main purpose of the formal definition of the patching function?',
#    'role': 'user'},
#   {'content': 'to formally describe the process of segmenting bytes into patches',
#    'role': 'assistant'}]}

# %% [markdown]
# Finally free vLLM process to save memory and to allow for finetuning!

# %%
generator.cleanup()
# Out:
# Attempting to terminate the VLLM server gracefully...
# Server terminated gracefully.

# %% [markdown]
# ### Fine-tuning Synthetic Dataset with Unsloth

# %%
from unsloth import FastLanguageModel
import torch

fourbit_models = [
    # 4bit dynamic quants for superior accuracy and low memory use
    "unsloth/gemma-3-4b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-12b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-27b-it-unsloth-bnb-4bit",
    # Qwen3 new models
    "unsloth/Qwen3-4B-unsloth-bnb-4bit",
    "unsloth/Qwen3-8B-unsloth-bnb-4bit",
    # Other very popular models!
    "unsloth/Llama-3.1-8B",
    "unsloth/Llama-3.2-3B",
    "unsloth/Llama-3.3-70B",
    "unsloth/mistral-7b-instruct-v0.3",
    "unsloth/Phi-4",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-3B-Instruct",
    max_seq_length = 2048, # Choose any for long context!
    load_in_4bit = True,  # 4 bit quantization to reduce memory
    load_in_8bit = False, # [NEW!] A bit more accurate, uses 2x memory
    full_finetuning = False, # [NEW!] We have full finetuning now!
    # token = "hf_...", # use one if using gated models
)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipython-input-439418653.py in <cell line: 0>()
# ----> 1 from unsloth import FastLanguageModel
#       2 import torch
#       3
#       4 fourbit_models = [
#       5     # 4bit dynamic quants for superior accuracy and low memory use
#
# /usr/local/lib/python3.12/dist-packages/unsloth/__init__.py in <module>
#      96     raise NotImplementedError("Unsloth currently only works on NVIDIA, AMD and Intel GPUs.")
#      97 pass
# ---> 98 DEVICE_TYPE : str = get_device_type()
#      99 # HIP fails for autocast and other torch functions. Use CUDA instead
#     100 DEVICE_TYPE_TORCH = DEVICE_TYPE
#
# /usr/local/lib/python3.12/dist-packages/unsloth/__init__.py in get_device_type()
#      86     if hasattr(torch, "accelerator"):
#      87         if not torch.accelerator.is_available():
# ---> 88             raise NotImplementedError("Unsloth cannot find any torch accelerator? You need a GPU.")
#      89         accelerator = str(torch.accelerator.current_accelerator())
#      90         if accelerator in ("cuda", "xpu", "hip"):
#
# NotImplementedError: Unsloth cannot find any torch accelerator? You need a GPU.

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.4.3 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the `Llama-3.2` format for conversation style finetunes. The chat template renders conversations like below: (Cutting Knowledge Date is by default there!)
#
# ```
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 01 May 2025
#
# You are a helpful assistant.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is 1+1?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# 2<|eot_id|>
# ```

# %%
# !ls -l

# %%
def formatting_prompts_func(examples):
    convos = examples["messages"]
    texts = [tokenizer.apply_chat_template(convo, tokenize = False, add_generation_prompt = False) for convo in convos]
    return { "text" : texts, }

# Get our previous dataset and format it:
dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Map:   0%|          | 0/35 [00:00<?, ? examples/s]

# %% [markdown]
# See result of the first row:

# %%
dataset[0]
# Out:
# {'messages': [{'content': 'You are a helpful assistant.', 'role': 'system'},
#   {'content': 'What is the primary unit of computation in the Byte Latent Transformer (BLT) architecture?',
#    'role': 'user'},
#   {'content': 'Patches', 'role': 'assistant'}],
#  'text': '<|begin_of_text|><|start_header_id|>system<|end_header_id|>\n\nCutting Knowledge Date: December 2023\nToday Date: 01 May 2025\n\nYou are a helpful assistant.<|eot_id|><|start_header_id|>user<|end_header_id|>\n\nWhat is the primary unit of computation in the Byte Latent Transformer (BLT) architecture?<|eot_id|><|start_header_id|>assistant<|end_header_id|>\n\nPatches<|eot_id|>'}

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's train our model. We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`.

# %%
from trl import SFTTrainer, SFTConfig

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    eval_dataset = None, # Can set up evaluation!
    args = SFTConfig(
        dataset_text_field = "text",
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4, # Use GA to mimic batch size!
        warmup_steps = 5,
        max_steps = 60,
        learning_rate = 2e-4,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/35 [00:00<?, ? examples/s]

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 3.441 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 35 | Num Epochs = 15 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 24,313,856/3,000,000,000 (0.81% trained)
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 01:47, Epoch 12/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.770500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.901100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.770800</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.705000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.940100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.610800</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.617000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.426600</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.255000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.410500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.328100</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.193000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.215000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.027200</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.933600</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.976800</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.928700</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.865900</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.956300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.925800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.853600</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.663600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.772600</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.609900</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.634200</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.556100</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.489200</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.523400</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.465100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.545400</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.373400</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.358500</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.344900</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.302400</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.400300</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.294800</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.272400</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.264200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.233400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.244500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.212200</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.192300</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.177500</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.175400</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.176100</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.146400</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.142300</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.133200</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.132700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.147300</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.118800</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.116800</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.106100</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.101200</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.101300</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.096300</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.103200</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.099000</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.107300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.105100</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 110.0157 seconds used for training.
# 1.83 minutes used for training.
# Peak reserved memory = 3.441 GB.
# Peak reserved memory for training = 0.0 GB.
# Peak reserved memory % of max memory = 23.343 %.
# Peak reserved memory for training % of max memory = 0.0 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! Use `apply_chat_template` with `add_generation_prompt` set to `True` for inference.

# %%
messages = [
    {"role": "user", "content": "What is the Byte Latent Transformer?"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(input_ids = inputs, streamer = text_streamer,
                   max_new_tokens = 256, temperature = 0.1)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# A novel architecture that uses patches to encode bytes<|eot_id|>

# %% [markdown]
# The model learns about the research paper!!

# %%
messages = [
    {"role": "user", "content": "What are some benefits of the BLT?"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(input_ids = inputs, streamer = text_streamer,
                   max_new_tokens = 256, temperature = 0.1)
# Out:
# Improved inference capabilities, enhanced model robustness, and the ability to scale while maintaining a fixed-inference budget<|eot_id|>

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model")  # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
messages = [
    {"role": "user", "content": "What is so special about BLT's tokenization?"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(input_ids = inputs, streamer = text_streamer,
                   max_new_tokens = 256, temperature = 0.1)
# Out:
# It dynamically groups bytes into patches preserving access to the byte-level information<|eot_id|>

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False:
    model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: # Change to True to upload finetune
    model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False:
    model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: # Change to True to upload finetune
    model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False:
    model.save_pretrained("model")
    tokenizer.save_pretrained("model")
if False: # Change to True to upload finetune
    model.push_to_hub("hf/model", token = "")
    tokenizer.push_to_hub("hf/model", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# Save to 8bit Q8_0
if False:
    model.save_pretrained_gguf("model", tokenizer,)
if False: # Change to True to upload finetune
    model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False:
    model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: # Change to True to upload finetune
    model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False:
    model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: # Change to True to upload finetune
    model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp.
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>

# %%
# 把QA pairs的乱码转换成utf8编码
import json
import os

output_dir = "/content/drive/MyDrive/ColabNotebooks/data/generated/"
file_paths = [os.path.join(output_dir, f) for f in os.listdir(output_dir) if os.path.isfile(os.path.join(output_dir, f))]


for file_path in file_paths:
    if not os.path.exists(file_path):
        print(f"Warning: File not found at {file_path}. Skipping.")
        continue

    try:
        # Read the JSON data with explicit UTF-8 encoding
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)

        # Save the data back to the same file with explicit UTF-8 encoding
        # ensure_ascii=False is crucial for preserving non-ASCII characters
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=4, ensure_ascii=False)

        print(f"Successfully processed and re-saved: {file_path}")

    except json.JSONDecodeError:
        print(f"Error: Could not decode JSON from {file_path}. Skipping.")
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}. Skipping.")

print("\nFinished processing files.")
# Out:
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_0_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_1_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_10_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_100_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_101_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_102_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_103_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_104_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_105_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_106_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_107_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_108_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_109_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_11_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_110_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_111_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_112_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_113_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_114_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_115_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_116_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_117_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_118_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_119_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_12_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_120_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_121_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_122_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_123_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_124_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_125_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_126_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_127_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_128_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_129_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_13_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_130_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_131_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_132_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_133_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_134_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_135_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_136_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_137_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_138_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_139_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_14_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_140_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_141_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_142_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_143_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_144_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_145_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_146_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_147_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_148_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_149_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_15_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_150_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_151_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_152_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_153_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_154_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_155_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_156_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_157_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_158_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_159_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_16_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_160_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_161_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_162_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_163_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_164_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_165_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_166_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_167_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_168_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_169_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_17_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_170_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_171_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_172_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_173_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_174_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_175_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_176_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_177_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_178_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_179_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_18_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_180_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_181_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_182_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_183_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_184_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_185_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_186_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_187_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_188_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_189_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_19_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_190_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_191_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_192_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_193_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_194_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_195_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_196_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_197_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_198_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_199_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_2_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_20_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_200_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_201_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_202_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_203_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_204_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_205_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_206_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_207_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_208_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_209_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_21_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_210_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_211_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_212_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_213_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_214_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_215_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_216_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_217_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_218_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_219_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_22_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_220_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_221_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_222_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_223_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_224_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_225_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_226_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_227_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_228_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_229_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_23_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_230_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_231_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_232_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_233_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_234_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_235_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_236_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_237_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_238_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_239_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_24_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_240_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_241_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_242_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_243_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_244_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_245_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_246_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_247_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_248_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_249_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_25_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_250_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_251_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_252_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_253_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_254_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_255_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_256_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_257_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_258_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_259_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_26_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_260_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_261_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_262_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_263_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_264_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_265_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_266_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_267_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_268_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_269_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_27_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_270_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_271_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_272_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_273_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_274_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_275_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_276_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_277_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_278_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_279_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_28_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_280_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_281_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_282_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_283_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_284_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_285_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_286_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_287_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_288_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_289_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_29_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_290_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_291_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_292_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_293_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_294_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_295_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_296_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_297_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_298_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_299_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_3_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_30_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_300_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_301_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_302_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_303_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_304_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_305_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_306_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_307_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_308_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_309_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_31_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_310_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_311_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_312_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_313_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_314_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_315_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_316_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_317_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_318_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_319_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_32_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_320_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_321_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_322_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_323_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_324_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_325_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_326_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_327_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_328_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_329_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_33_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_330_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_331_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_332_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_333_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_334_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_335_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_336_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_337_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_338_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_339_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_34_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_340_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_341_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_342_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_343_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_344_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_345_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_346_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_347_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_348_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_349_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_35_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_350_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_351_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_352_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_353_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_354_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_355_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_356_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_357_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_358_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_359_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_36_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_360_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_361_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_362_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_363_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_364_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_365_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_366_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_367_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_368_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_369_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_37_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_370_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_371_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_372_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_373_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_374_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_375_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_376_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_377_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_378_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_379_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_38_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_380_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_381_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_382_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_383_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_384_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_385_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_386_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_387_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_388_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_389_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_39_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_390_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_391_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_392_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_393_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_394_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_395_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_396_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_397_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_398_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_399_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_4_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_40_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_400_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_401_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_402_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_403_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_404_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_405_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_406_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_407_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_408_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_409_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_41_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_410_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_411_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_412_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_413_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_414_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_415_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_416_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_417_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_418_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_419_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_42_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_420_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_421_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_422_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_423_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_424_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_425_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_426_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_427_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_428_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_429_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_43_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_430_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_431_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_432_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_433_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_434_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_435_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_436_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_437_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_438_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_439_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_44_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_440_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_441_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_442_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_443_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_444_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_445_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_446_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_447_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_448_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_449_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_45_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_450_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_451_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_452_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_453_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_454_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_455_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_456_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_457_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_458_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_459_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_46_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_460_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_461_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_462_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_463_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_464_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_465_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_466_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_467_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_468_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_469_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_47_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_470_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_471_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_472_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_473_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_474_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_475_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_476_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_477_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_478_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_479_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_48_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_480_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_481_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_482_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_483_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_484_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/huan2-merged_cleaned_485_qa_pairs.json
# Successfully processed and re-saved: /content/drive/MyDrive/ColabNotebooks/data/generated/test_write.json
#
# Finished processing files.
